# %%
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
import glob

import numpy as np
import pandas as pd
from scipy.signal import medfilt, find_peaks

import efmlib

# %%
show_plots = True

# %% [markdown]
# ## Read data and make an initial plot so we can decide on launch

# %%
# Get sonde file
df_sonde = pd.read_csv('/data/LEE/Radiosonde_QC/LEENSSL2_pyqc20230706171937_20221218_035910.csv', parse_dates=['Time'])

#Get EFM files:
filenames = sorted(glob.glob('/data/LEE/IOP4/Blizzard/EFM*.TXT'))
df_gps, df_fiber = efmlib.io.read_efm_raw(filenames[:])
# Out:
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM00.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM01.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM02.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM03.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM04.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM05.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM06.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM07.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM08.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM09.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM10.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM11.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM12.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM13.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM14.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM15.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM16.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM17.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM18.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM19.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM20.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM21.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM22.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM23.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM24.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM25.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM26.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM27.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM28.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM29.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM30.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM31.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM32.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM33.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM34.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM35.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM36.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM37.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM38.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM39.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM40.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM41.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM42.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM43.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM44.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM45.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM46.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM47.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM48.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM49.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM50.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM51.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM52.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM53.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM54.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM55.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM56.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM57.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM58.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM59.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM60.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM61.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM62.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM63.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM64.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM65.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM66.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM67.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM68.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM69.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM70.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM71.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM72.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM73.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM74.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM75.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM76.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM77.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM78.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM79.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM80.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM81.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM82.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM83.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM84.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM85.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM86.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM87.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM88.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM89.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM90.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM91.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM92.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM93.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM94.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM95.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM96.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM97.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM98.TXT'>.TXT
# <_io.BufferedReader name='/data/LEE/IOP4/Blizzard/EFM99.TXT'>.TXT

# %%
if show_plots == True:
    # print('-> Figures:')
    fields = ['adc_volts', 'acceleration_x', 'acceleration_y', 'acceleration_z',
              'magnetometer_x', 'magnetometer_y', 'magnetometer_z', 
              'gyroscope_x', 'gyroscope_y', 'gyroscope_z', 
              'temperature', 'adc_ready_millis']
    fig, axes = plt.subplots(figsize=(10, 20), nrows=len(fields), sharex=True)
    for fname, ax in zip(fields, axes):
        ax.plot(df_fiber[fname], color='k')
        ax.set_ylabel(fname)
    axes[-1].set_xlabel('Sample')
    fig.tight_layout()
    axes[0].set_ylim(-1, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Mark launch and do sample QC after that time

# %%
# Zoom into plot, look for a sudden increase in magnitude in the z-axis accelerometer and magnetomter.
launch_sample = 42523

# Strictly speaking, the flight ends at full_end_trim, but after the chosen end_trim there isn't good spin.
# full_end_trim = 214500
end_trim = 88000

# Also have some uncorrectable errors here, so truncate.
# launch_sample + 34932 = 77455
end_trim=77000

# %%
df_fiber = efmlib.qc.df_fiber_filter(df_fiber[launch_sample:end_trim].reset_index())                      #Quality control
# Out:
# Removing inserted junk data
# indentifying sections that need reconstruction
# removing excess samples from reconstructed regions
# attempting to reconstruct regions with cosine functions
# Removing outlier noise

# %%
if show_plots == True:
    # print('-> Figures:')
    fields = ['adc_volts', 'acceleration_x', 'acceleration_y', 'acceleration_z',
              'magnetometer_x', 'magnetometer_y', 'magnetometer_z', 
              'gyroscope_x', 'gyroscope_y', 'gyroscope_z', 
              'temperature', 'adc_ready_millis']
    fig, axes = plt.subplots(figsize=(10, 20), nrows=len(fields), sharex=True)
    for fname, ax in zip(fields, axes):
        ax.plot(df_fiber[fname], color='k')
        ax.set_ylabel(fname)
    axes[-1].set_xlabel('Sample')
    fig.tight_layout()
    # axes[0].set_ylim(-1, 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# DRAFT: Bandpass filter the accelerometer signals, and then normalize by the total 
# length of the acceleration vector. Will naturally remove the centrifugal component, too. 
# For a quick hack at polarity, also bandpass filter the ADC signal the same way 
# as the acceleromter, then multiply and low pass filter to get a (hopefully slowly varying) polarity signal.

fs = 45.45
f_spin = efmlib.signal.freq_peak(df_fiber['acceleration_x'], fs)[0]
print("Spin rate from peak frequency is ", f_spin)

df_fiber, passband, bp_sos = efmlib.signal.normalize_accelerometer(df_fiber, fs=fs)
# Set the low pass cutoff at the same point as the lower end of the accelerometer passband. It's convenient.
lp_cut = passband[0]
adc_polarity_bp, lp_sos, adc_polarity, adc_sign = efmlib.signal.simplistic_E_polarity(df_fiber, bp_sos, lp_cut, fs=fs)
# Out:
# Spin rate from peak frequency is  1.5755076625545756

# %% [markdown]
# ### Find peak-to-peak E and calibrate it

# %%
def find_peak_to_peak(adc, distance=9):
    peak_idx, peak_data         = find_peaks(adc, distance=distance)
    neg_peak_idx, neg_peak_data = find_peaks(-adc, distance=distance)
    n_peaks = min(peak_idx.shape[0], neg_peak_idx.shape[0])

    estimate_idxrange = 0, adc.shape[0]
    
    
    max_idx_critter = (peak_idx >= estimate_idxrange[0]) & (peak_idx < estimate_idxrange[1])
    min_idx_critter = (neg_peak_idx >= estimate_idxrange[0]) & (neg_peak_idx < estimate_idxrange[1])
    target_max_peak = peak_idx[max_idx_critter]
    target_min_peak = neg_peak_idx[min_idx_critter]
    peak_peak_range = (adc[target_max_peak]).max() - (adc[target_min_peak]).min()

    # This is a bad way to match up the peaks, since it assumes that there is an alternating set of positive
    # and negative peaks, instead of matching them by index.
    peak_peak_range = adc[peak_idx[:n_peaks]] - adc[neg_peak_idx[:n_peaks]]

    print('Number of peak samples:',peak_peak_range.shape[0])
    
    return peak_idx[:n_peaks], neg_peak_idx[:n_peaks], peak_peak_range

# %%
#Now extract peak voltages to separate array:
#------
# This is not ideal, but max of maxes minus min of mins is an ok estimate of the peak to peak voltage.

adc_samples = df_fiber['adc_volts'].values

peak_idx, neg_peak_idx, peak_peak_range = find_peak_to_peak(adc_samples)
E_calibrated_mag = efmlib.calibration.calibrated_E(peak_peak_range)
# Out:
# Number of peak samples: 1170

# %%
#Plot raw voltage signal with identified peaks (red)
#---------
print('Displaying Peaks of raw voltage source (interpolated).')
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(peak_idx, adc_samples[peak_idx], 
        color='r', marker='s', linewidth=None, markersize=3,alpha=0.6)
ax.plot(neg_peak_idx, adc_samples[neg_peak_idx], 
        color='r', marker='s', linewidth=None, markersize=3,alpha=0.6)

ax.plot(adc_samples, color='k', marker=None, linewidth=.2, markersize=2,alpha=0.8)
ax.set_ylabel('ADC [Volts]')
ax.grid(alpha=0.3)
# Out:
# Displaying Peaks of raw voltage source (interpolated).
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot voltage peaks only:
#-------
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(peak_peak_range,color='k',linewidth=1)
ax.set_xlabel('Peak sequence number')
ax.set_ylabel('ADC Peaks [Volts]')
ax.grid(alpha=0.3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot calibrated voltage to electric field signal:
#-------
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(E_calibrated_mag,color='k',linewidth=1)
ax.set_xlabel('Peak sequence number')
ax.set_ylabel('Electric field (V/m)')
ax.grid(alpha=0.3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
max_E = np.empty_like(adc_samples)*np.nan

# use the average of the peak indices as the representative sample for the peak-to-peak E.
max_E_idx = ((peak_idx+neg_peak_idx)/2.0).astype(int)

max_E[max_E_idx] = E_calibrated_mag

# Would be nice to LPF interpolate here before assigning back.
df_fiber['max_E'] = max_E * adc_sign

# %% [markdown]
# ## Align EFM and sonde data

# %%
df_fiber.columns
# Out:
# Index(['index', 'start_byte', 'adc_ready_millis', 'adc_reading',
#        'magnetometer_x', 'magnetometer_y', 'magnetometer_z', 'gyroscope_x',
#        'gyroscope_y', 'gyroscope_z', 'acceleration_x', 'acceleration_y',
#        'acceleration_z', 'temperature', 'relative_humidity', 'pressure',
#        'end_byte', 'adc_volts', 'acceleration_x_bp', 'acceleration_y_bp',
#        'acceleration_z_bp', 'max_E'],
#       dtype='object')

# %%
sonde_time_var = 'Time'
launch_time = df_sonde[sonde_time_var].values[0]
df_fiber[sonde_time_var]= launch_time + (df_fiber.adc_ready_millis - df_fiber.adc_ready_millis[0]).values.astype('timedelta64[ms]')

# %%
# Resample EFM data to 1 s
df_EFMsecond = df_fiber.set_index('Time').fillna(method='ffill').resample('1s').max()
df_merged = df_sonde.set_index('Time')
df_merged['max_E'] = df_EFMsecond.max_E

df_merged['T_C'] = df_merged['Filtered Temperature (K)'] - 273.15
df_merged['Td_C'] = df_merged['Filtered Dewpoint (K)'] - 273.15
df_merged['alt_km'] = df_merged['Filtered Altitude (m)']/1000.0

# df_merged

# %%
from scipy.ndimage import uniform_filter

E_smoothed = uniform_filter(df_merged.max_E, 5)

raw_charge_density = 8.854e-12*np.gradient(E_smoothed, df_merged.alt_km*1000)
charge_density_nCm3 = np.abs(
    uniform_filter(raw_charge_density * 1e9, 7)
)

# %%
fig, (ax, ax_rho) = plt.subplots(1,2, figsize=(8.5, 11), 
                                 gridspec_kw={'width_ratios': [0.8, 0.2]}, sharey=True)
ax.plot(-E_smoothed/1000.0, df_merged.alt_km, color='k', label='$-|E|$ (kV/m)')
ax.plot(df_merged.T_C, df_merged.alt_km, color='b', label='$T$ (C)')
ax.plot(df_merged.Td_C, df_merged.alt_km, color='g', label='$T_d$ (C)')
ax.legend()
ax.set_xlim(-80,80)
ax.set_ylim(0, 8)
ax.set_ylabel('Altitude (km)')

ax_rho.plot(charge_density_nCm3, df_merged.alt_km, color='r')
ax_rho.set_xlabel('Charge density\n(nC/m$^3$)')
# Out:
# Text(0.5, 0, 'Charge density\n(nC/m$^3$)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
